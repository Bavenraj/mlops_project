# %%
import pandas as pd

data = pd.read_csv('fireendt.txt', delimiter = '~', encoding= 'unicode_escape')
print(len(data))
# Out:
# C:\Users\bavenraj.partipan\AppData\Local\Temp\ipykernel_1888\2605793496.py:3: DtypeWarning: Columns (24,35,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('fireendt.txt', delimiter = '~', encoding= 'unicode_escape')
# 57005

# %%
data.head()
# Out:
#       POLICY NUMBER        ENDORSEMENT NO ENDT CODE             ENDT DESC  \
# 0  11-250-22-000267  11-250-22-000267*001        18  AMENDMENT OF PREMIUM
# 1  11-250-22-000267  11-250-22-000267*001        18  AMENDMENT OF PREMIUM
# 2  11-250-22-000267  11-250-22-000267*001        18  AMENDMENT OF PREMIUM
# 3  11-250-22-000267  11-250-22-000267*001        18  AMENDMENT OF PREMIUM
# 4  11-250-22-000267  11-250-22-000267*001        18  AMENDMENT OF PREMIUM
#
#                INSURED NAME INSURED TYPE BUSINESS REG NO           IC NO  \
# 0  ELIZABETH AK HENRY ROMOI          NaN             NaN  561119-13-5018
# 1  ELIZABETH AK HENRY ROMOI          NaN             NaN  561119-13-5018
# 2  ELIZABETH AK HENRY ROMOI          NaN             NaN  561119-13-5018
# 3  ELIZABETH AK HENRY ROMOI          NaN             NaN  561119-13-5018
# 4  ELIZABETH AK HENRY ROMOI          NaN             NaN  561119-13-5018
#
#   AGENT CODE                      AGENT NAME  ... STAMP     TOTAL PREMIUM  \
# ...

# %%
data.columns = data.columns.str.replace(' ', '_')
data.head()
# Out:
#       POLICY_NUMBER        ENDORSEMENT_NO ENDT_CODE             ENDT_DESC  \
# 0  11-250-22-000267  11-250-22-000267*001        18  AMENDMENT OF PREMIUM
# 1  11-250-22-000267  11-250-22-000267*001        18  AMENDMENT OF PREMIUM
# 2  11-250-22-000267  11-250-22-000267*001        18  AMENDMENT OF PREMIUM
# 3  11-250-22-000267  11-250-22-000267*001        18  AMENDMENT OF PREMIUM
# 4  11-250-22-000267  11-250-22-000267*001        18  AMENDMENT OF PREMIUM
#
#                INSURED_NAME INSURED_TYPE BUSINESS_REG_NO           IC_NO  \
# 0  ELIZABETH AK HENRY ROMOI          NaN             NaN  561119-13-5018
# 1  ELIZABETH AK HENRY ROMOI          NaN             NaN  561119-13-5018
# 2  ELIZABETH AK HENRY ROMOI          NaN             NaN  561119-13-5018
# 3  ELIZABETH AK HENRY ROMOI          NaN             NaN  561119-13-5018
# 4  ELIZABETH AK HENRY ROMOI          NaN             NaN  561119-13-5018
#
#   AGENT_CODE                      AGENT_NAME  ... STAMP     TOTAL_PREMIUM  \
# ...
